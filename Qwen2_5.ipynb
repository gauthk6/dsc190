# %% [markdown]
# **ONLY RUN IN COLAB WITH GPU ENABLED**

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from PIL import Image
import requests

# %%
# Install required packages
# !pip install auto-gptq transformers accelerate pillow optimum qwen-vl-utils
# Out:
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (11.0.0)
# Collecting optimum
#   Downloading optimum-1.23.3-py3-none-any.whl.metadata (20 kB)
# Collecting qwen-vl-utils
#   Downloading qwen_vl_utils-0.0.8-py3-none-any.whl.metadata (3.6 kB)
# Collecting datasets (from auto-gptq)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.26.4)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.2.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.5.1+cu121)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.4.5)
# Requirement already satisfied: peft>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.13.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.66.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.13.1)
# Collecting av (from qwen-vl-utils)
#   Downloading av-13.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->auto-gptq)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (2.2.2)
# Collecting xxhash (from datasets->auto-gptq)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->auto-gptq)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.23.2->transformers)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.11.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2024.2)
# Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 41.5 MB/s eta 0:00:00
# Downloading optimum-1.23.3-py3-none-any.whl (424 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 424.1/424.1 kB 32.4 MB/s eta 0:00:00
# Downloading qwen_vl_utils-0.0.8-py3-none-any.whl (5.9 kB)
# Downloading av-13.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 19.6 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.4 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 33.7 MB/s eta 0:00:00
# Downloading gekko-1.2.1-py3-none-any.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 67.5 MB/s eta 0:00:00
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.2 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 19.5 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.9 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, rouge, humanfriendly, gekko, fsspec, dill, av, qwen-vl-utils, multiprocess, coloredlogs, datasets, optimum, auto-gptq
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed auto-gptq-0.7.1 av-13.1.0 coloredlogs-15.0.1 datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 gekko-1.2.1 humanfriendly-10.0 multiprocess-0.70.16 optimum-1.23.3 qwen-vl-utils-0.0.8 rouge-1.0.1 xxhash-3.5.0

# %%
from transformers import Qwen2VLForConditionalGeneration, AutoProcessor
from PIL import Image
from qwen_vl_utils import process_vision_info

# Load the model and processor
model = Qwen2VLForConditionalGeneration.from_pretrained(
    "Qwen/Qwen2-VL-2B-Instruct",
    torch_dtype="auto",
    device_map="auto"
)

min_pixels = 256 * 28 * 28
max_pixels = 1280 * 28 * 28

processor = AutoProcessor.from_pretrained(
"Qwen/Qwen2-VL-2B-Instruct", min_pixels=min_pixels, max_pixels=max_pixels
)
# Out:
# config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/56.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/429M [00:00<?, ?B/s]
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]

# %%
# Load the image
image_path = '/content/bio_image.png'
image = Image.open(image_path)

prompt = """
Generate a detailed paragraph description of this scientific figure that:
1. Starts with the complete figure number and reference
2. Flows naturally while incorporating these key elements:
   - The type of visualization and technical specifications (e.g., microscopy type, magnification, scale)
   - Description of what is being shown and how it's organized in the image
   - Any staining, coloring, or visual techniques used
   - Quantitative measurements or comparisons present
   - Key features or differences being demonstrated
   - The biological/chemical concept being illustrated
   - Educational purpose of the figure
3. Ends with any figure credits or attributions

Write as a single cohesive paragraph that naturally integrates the caption information with visual details. Focus on details that would help distinguish this figure from similar ones in a textbook. Avoid bullet points or sectioned formatting. Use natural transitions and maintain a scientific tone.
"""

# Prepare the messages format
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
                "image": image,  # Pass the PIL Image directly
            },
            {"type": "text", "text": prompt},
        ],
    }
]

# Prepare inputs for inference
text = processor.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt"
)
inputs = inputs.to("cuda")  # Or use "cpu" if you don't have a GPU

# Generate the response
generated_ids = model.generate(**inputs, max_new_tokens=512,early_stopping=True)
generated_ids_trimmed = [
    out_ids[len(in_ids):] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
response = processor.batch_decode(
    generated_ids_trimmed,
    skip_special_tokens=True,
    clean_up_tokenization_spaces=False
)[0]

print(response)
# Out:
# Figure 4.4, titled "These uterine cervix cells, viewed through a light microscope, are from a Pap smear. Normal cells are on the left. The cells on the right are infected with human papillomavirus (HPV). Notice that the infected cells are larger. Also, two of these cells each have two nuclei instead of one, the normal number." This figure is a light microscopic visualization of uterine cervix cells from a Pap smear. The cells are stained blue, indicating the presence of a specific stain or dye. The cells are organized in a two-column format, with the left column representing normal cells and the right column representing infected cells. The infected cells are larger and have two nuclei instead of the normal number of one. The scale bar at the bottom of the image indicates that each unit represents 10 micrometers. The figure is a modification of work by Ed Uthman, MD, and the scale bar data is from Matt Russell. This figure serves as an educational tool to illustrate the differences between normal and infected uterine cervix cells, which can be used to diagnose and monitor cervical health.

# %%
import os
import json
import time
from pathlib import Path
from datetime import datetime
from transformers import Qwen2VLForConditionalGeneration, AutoProcessor
from PIL import Image
from qwen_vl_utils import process_vision_info
import torch

def format_time(seconds):
    """Convert seconds to human readable time format"""
    hours = seconds // 3600
    minutes = (seconds % 3600) // 60
    seconds = seconds % 60
    return f"{int(hours)}h {int(minutes)}m {int(seconds)}s"

def process_single_image(image_path, model, processor, prompt):
    """Process a single image following the known working pattern"""
    try:
        # Load the image
        image = Image.open(image_path)

        # Prepare the messages format
        messages = [
            {
                "role": "user",
                "content": [
                    {
                        "type": "image",
                        "image": image,
                    },
                    {"type": "text", "text": prompt},
                ],
            }
        ]

        # Prepare inputs for inference
        text = processor.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True
        )
        image_inputs, video_inputs = process_vision_info(messages)

        if image_inputs is None:
            raise ValueError("process_vision_info returned None for image inputs")

        inputs = processor(
            text=[text],
            images=image_inputs,
            videos=video_inputs,
            padding=True,
            return_tensors="pt"
        )
        inputs = inputs.to(model.device)

        # Generate the response
        generated_ids = model.generate(
            **inputs,
            max_new_tokens=512,
            early_stopping=True
        )
        generated_ids_trimmed = [
            out_ids[len(in_ids):]
            for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
        ]
        response = processor.batch_decode(
            generated_ids_trimmed,
            skip_special_tokens=True,
            clean_up_tokenization_spaces=False
        )[0]

        return response.strip()

    except Exception as e:
        print(f"Error processing {image_path}: {str(e)}")
        return None

def process_images_in_folder(input_folder, output_jsonl, batch_size=1, max_images=None):
    """
    Process images in a folder and save descriptions to a JSONL file
    """
    print("\n=== Starting Image Processing Pipeline ===")
    start_time = time.time()

    # Load the model and processor
    print("\nInitializing model and processor...")
    model = Qwen2VLForConditionalGeneration.from_pretrained(
        "Qwen/Qwen2-VL-2B-Instruct",
        torch_dtype="auto",
        device_map="auto"
    )

    min_pixels = 256 * 28 * 28
    max_pixels = 1280 * 28 * 28

    processor = AutoProcessor.from_pretrained(
        "Qwen/Qwen2-VL-2B-Instruct",
        min_pixels=min_pixels,
        max_pixels=max_pixels
    )
    print("Model initialization complete!")

    # Define the prompt template
    prompt = """Generate a detailed paragraph description of this scientific figure that:
1. Starts with the complete figure number and reference
2. Flows naturally while incorporating these key elements:
   - The type of visualization and technical specifications (e.g., microscopy type, magnification, scale)
   - Description of what is being shown and how it's organized in the image
   - Any staining, coloring, or visual techniques used
   - Quantitative measurements or comparisons present
   - Key features or differences being demonstrated
   - The biological/chemical concept being illustrated
   - Educational purpose of the figure
3. Ends with any figure credits or attributions

Write as a single cohesive paragraph that naturally integrates the caption information with visual details. Focus on details that would help distinguish this figure from similar ones in a textbook. Avoid bullet points or sectioned formatting. Use natural transitions and maintain a scientific tone."""

    # Get list of image files
    print("\nScanning for images...")
    image_extensions = {'.png', '.jpg', '.jpeg', '.tiff', '.bmp'}
    image_files = [
        f for f in Path(input_folder).glob('*')
        if f.suffix.lower() in image_extensions
    ]
    total_images = len(image_files)
    print(f"Found {total_images} images to process")

    # Check for existing progress
    existing_processed = set()
    if os.path.exists(output_jsonl):
        with open(output_jsonl, 'r', encoding='utf-8') as f:
            for line in f:
                try:
                    data = json.loads(line)
                    existing_processed.add(data['img_path'])
                except:
                    continue

    remaining_images = [f for f in image_files if str(f) not in existing_processed]

    # Apply max_images limit if specified
    if max_images is not None:
        remaining_to_process = max_images - len(existing_processed)
        if remaining_to_process <= 0:
            print(f"\nAlready processed {len(existing_processed)} images, which meets or exceeds the requested max_images={max_images}")
            return
        remaining_images = remaining_images[:remaining_to_process]
        print(f"Will process {len(remaining_images)} more images to reach max_images={max_images}")

    print(f"Found {len(existing_processed)} previously processed images")
    print(f"{len(remaining_images)} images remaining to process")

    if not remaining_images:
        print("\nAll images have already been processed!")
        return

    processed_count = len(existing_processed)
    errors_count = 0

    print("\n=== Starting Processing ===")
    print(f"Processing in batches of {batch_size} images")

    # Process images in batches
    for i in range(0, len(remaining_images), batch_size):
        batch_files = remaining_images[i:i + batch_size]
        batch_start_time = time.time()

        print(f"\nProcessing batch {i//batch_size + 1}/{(len(remaining_images) + batch_size - 1)//batch_size}")
        print(f"Batch contains {len(batch_files)} images")

        # Process each image in the batch
        for img_path in batch_files:
            print(f"\nProcessing {img_path.name}")
            response = process_single_image(img_path, model, processor, prompt)

            if response is not None:
                # Save successful result
                result = {
                    'img_path': str(img_path),
                    'description': response
                }

                with open(output_jsonl, 'a', encoding='utf-8') as f:
                    json.dump(result, f, ensure_ascii=False)
                    f.write('\n')

                processed_count += 1
                print(f"Successfully processed {img_path.name}")
            else:
                errors_count += 1

        # Calculate and display progress statistics
        batch_time = time.time() - batch_start_time
        elapsed_time = time.time() - start_time
        remaining_images_count = total_images - processed_count

        if processed_count > 0:
            avg_time_per_image = elapsed_time / processed_count
            estimated_remaining_time = remaining_images_count * avg_time_per_image

            print(f"\nBatch Progress Update:")
            print(f"├── Time for this batch: {format_time(batch_time)}")
            print(f"├── Average time per image: {format_time(avg_time_per_image)}")
            print(f"├── Total progress: {processed_count}/{total_images} ({(processed_count/total_images*100):.1f}%)")
            print(f"├── Total elapsed time: {format_time(elapsed_time)}")
            print(f"└── Estimated time remaining: {format_time(estimated_remaining_time)}")

        # Clear CUDA cache after each batch if using GPU
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    # Print final summary
    total_time = time.time() - start_time
    print("\n=== Processing Complete ===")
    print(f"Total time: {format_time(total_time)}")
    print(f"Images processed: {processed_count}/{total_images}")
    print(f"Errors encountered: {errors_count}")
    if processed_count > 0:
        print(f"Average time per image: {format_time(total_time/processed_count)}")
        print(f"Results saved to: {output_jsonl}")
    else:
        print("Average time per image: N/A - no images were processed")
        print("No results were saved as no images were successfully processed")

if __name__ == "__main__":
    # Example usage
    input_folder = "path/to/your/images"
    output_jsonl = "image_descriptions.jsonl"

    # Create output file if it doesn't exist
    if not os.path.exists(output_jsonl):
        open(output_jsonl, 'w').close()

# %%
  # Example usage
input_folder = "/content/Images"
output_jsonl = "image_descriptions.jsonl"

  # Create output file if it doesn't exist
if not os.path.exists(output_jsonl):
    open(output_jsonl, 'w').close()

# Process images with specified batch size and optional max_images limit
# Adjust batch_size based on your GPU memory
process_images_in_folder(
    input_folder=input_folder,
    output_jsonl=output_jsonl,
    batch_size=5,  # Adjust based on your GPU memory
    max_images=None  # Set to None to process all images
)
# Out:
# === Starting Image Processing Pipeline ===
#
# Initializing model and processor...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Model initialization complete!
#
# Scanning for images...
# Found 177 images to process
# Found 10 previously processed images
# 167 images remaining to process
#
# === Starting Processing ===
# Processing in batches of 5 images
#
# Processing batch 1/34
# Batch contains 5 images
#
# Processing chem_18.50.png
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:638: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# Successfully processed chem_18.50.png
#
# Processing bio4.7.png
# Successfully processed bio4.7.png
#
# Processing chem_7.18.png
# Successfully processed chem_7.18.png
#
# Processing chem_7.11.png
# Successfully processed chem_7.11.png
#
# Processing chem_6.19.png
# Successfully processed chem_6.19.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 2s
# ├── Average time per image: 0h 0m 8s
# ├── Total progress: 15/177 (8.5%)
# ├── Total elapsed time: 0h 2m 11s
# └── Estimated time remaining: 0h 23m 41s
#
# Processing batch 2/34
# Batch contains 5 images
#
# Processing chem_7.28.png
# Successfully processed chem_7.28.png
#
# Processing chem_7.24.png
# Successfully processed chem_7.24.png
#
# Processing chem_6.25.png
# Successfully processed chem_6.25.png
#
# Processing chem_6.22.png
# Successfully processed chem_6.22.png
#
# Processing chem_7.13.png
# Successfully processed chem_7.13.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 59s
# ├── Average time per image: 0h 0m 12s
# ├── Total progress: 20/177 (11.3%)
# ├── Total elapsed time: 0h 4m 11s
# └── Estimated time remaining: 0h 32m 51s
#
# Processing batch 3/34
# Batch contains 5 images
#
# Processing chem_7.15.png
# Successfully processed chem_7.15.png
#
# Processing chem_18.53.png
# Successfully processed chem_18.53.png
#
# Processing chem_7.23.png
# Successfully processed chem_7.23.png
#
# Processing bio4.4.png
# Successfully processed bio4.4.png
#
# Processing chem_18.13.png
# Successfully processed chem_18.13.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 36s
# ├── Average time per image: 0h 0m 13s
# ├── Total progress: 25/177 (14.1%)
# ├── Total elapsed time: 0h 5m 47s
# └── Estimated time remaining: 0h 35m 14s
#
# Processing batch 4/34
# Batch contains 5 images
#
# Processing chem_18.42.png
# Successfully processed chem_18.42.png
#
# Processing chem_6.13.png
# Successfully processed chem_6.13.png
#
# Processing chem_7.26.png
# Successfully processed chem_7.26.png
#
# Processing chem_18.40.png
# Successfully processed chem_18.40.png
#
# Processing chem_18.6.png
# Successfully processed chem_18.6.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 23s
# ├── Average time per image: 0h 0m 16s
# ├── Total progress: 30/177 (16.9%)
# ├── Total elapsed time: 0h 8m 11s
# └── Estimated time remaining: 0h 40m 7s
#
# Processing batch 5/34
# Batch contains 5 images
#
# Processing chem_18.15.png
# Successfully processed chem_18.15.png
#
# Processing chem_18.18.png
# Successfully processed chem_18.18.png
#
# Processing chem_18.22.png
# Successfully processed chem_18.22.png
#
# Processing chem_7.17.png
# Successfully processed chem_7.17.png
#
# Processing bio4.29.png
# Successfully processed bio4.29.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 42s
# ├── Average time per image: 0h 0m 16s
# ├── Total progress: 35/177 (19.8%)
# ├── Total elapsed time: 0h 9m 54s
# └── Estimated time remaining: 0h 40m 10s
#
# Processing batch 6/34
# Batch contains 5 images
#
# Processing chem_18.30.png
# Successfully processed chem_18.30.png
#
# Processing chem_7.9.png
# Successfully processed chem_7.9.png
#
# Processing chem_18.34.png
# Successfully processed chem_18.34.png
#
# Processing bio4.26.png
# Successfully processed bio4.26.png
#
# Processing bio7.19.png
# Successfully processed bio7.19.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 2s
# ├── Average time per image: 0h 0m 17s
# ├── Total progress: 40/177 (22.6%)
# ├── Total elapsed time: 0h 11m 57s
# └── Estimated time remaining: 0h 40m 56s
#
# Processing batch 7/34
# Batch contains 5 images
#
# Processing chem_7.20.png
# Successfully processed chem_7.20.png
#
# Processing chem_6.34.png
# Successfully processed chem_6.34.png
#
# Processing chem_18.4.png
# Successfully processed chem_18.4.png
#
# Processing chem_7.14.png
# Successfully processed chem_7.14.png
#
# Processing chem_18.1.png
# Successfully processed chem_18.1.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 2s
# ├── Average time per image: 0h 0m 18s
# ├── Total progress: 45/177 (25.4%)
# ├── Total elapsed time: 0h 13m 59s
# └── Estimated time remaining: 0h 41m 1s
#
# Processing batch 8/34
# Batch contains 5 images
#
# Processing chem_18.56.png
# Successfully processed chem_18.56.png
#
# Processing chem_18.25.png
# Successfully processed chem_18.25.png
#
# Processing chem_7.19.png
# Successfully processed chem_7.19.png
#
# Processing chem_18.44.png
# Successfully processed chem_18.44.png
#
# Processing chem_7.2.png
# Successfully processed chem_7.2.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 22s
# ├── Average time per image: 0h 0m 19s
# ├── Total progress: 50/177 (28.2%)
# ├── Total elapsed time: 0h 16m 21s
# └── Estimated time remaining: 0h 41m 32s
#
# Processing batch 9/34
# Batch contains 5 images
#
# Processing bio7.12.png
# Successfully processed bio7.12.png
#
# Processing chem_18.11.png
# Successfully processed chem_18.11.png
#
# Processing chem_18.7.png
# Successfully processed chem_18.7.png
#
# Processing chem_18.3.png
# Successfully processed chem_18.3.png
#
# Processing chem_18.35.png
# Successfully processed chem_18.35.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 57s
# ├── Average time per image: 0h 0m 19s
# ├── Total progress: 55/177 (31.1%)
# ├── Total elapsed time: 0h 18m 18s
# └── Estimated time remaining: 0h 40m 37s
#
# Processing batch 10/34
# Batch contains 5 images
#
# Processing chem_18.45.png
# Successfully processed chem_18.45.png
#
# Processing chem_6.28.png
# Successfully processed chem_6.28.png
#
# Processing chem_6.23.png
# Successfully processed chem_6.23.png
#
# Processing bio4.15.png
# Successfully processed bio4.15.png
#
# Processing chem_18.16.png
# Successfully processed chem_18.16.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 43s
# ├── Average time per image: 0h 0m 20s
# ├── Total progress: 60/177 (33.9%)
# ├── Total elapsed time: 0h 20m 2s
# └── Estimated time remaining: 0h 39m 4s
#
# Processing batch 11/34
# Batch contains 5 images
#
# Processing chem_6.12.png
# Successfully processed chem_6.12.png
#
# Processing bio7.1.png
# Successfully processed bio7.1.png
#
# Processing bio4.8a.png
# Successfully processed bio4.8a.png
#
# Processing chem_18.55.png
# Successfully processed chem_18.55.png
#
# Processing chem_6.33.png
# Successfully processed chem_6.33.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 16s
# ├── Average time per image: 0h 0m 20s
# ├── Total progress: 65/177 (36.7%)
# ├── Total elapsed time: 0h 22m 18s
# └── Estimated time remaining: 0h 38m 26s
#
# Processing batch 12/34
# Batch contains 5 images
#
# Processing chem_6.31.png
# Successfully processed chem_6.31.png
#
# Processing chem_6.35.png
# Successfully processed chem_6.35.png
#
# Processing chem_18.62.png
# Successfully processed chem_18.62.png
#
# Processing chem_7.1.png
# Successfully processed chem_7.1.png
#
# Processing chem_18.26.png
# Successfully processed chem_18.26.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 16s
# ├── Average time per image: 0h 0m 21s
# ├── Total progress: 70/177 (39.5%)
# ├── Total elapsed time: 0h 24m 34s
# └── Estimated time remaining: 0h 37m 34s
#
# Processing batch 13/34
# Batch contains 5 images
#
# Processing chem_18.61.png
# Successfully processed chem_18.61.png
#
# Processing chem_6.11.png
# Successfully processed chem_6.11.png
#
# Processing chem_6.30.png
# Successfully processed chem_6.30.png
#
# Processing bio4.22.png
# Successfully processed bio4.22.png
#
# Processing bio7.2.png
# Successfully processed bio7.2.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 11s
# ├── Average time per image: 0h 0m 21s
# ├── Total progress: 75/177 (42.4%)
# ├── Total elapsed time: 0h 26m 46s
# └── Estimated time remaining: 0h 36m 25s
#
# Processing batch 14/34
# Batch contains 5 images
#
# Processing bio4.20.png
# Successfully processed bio4.20.png
#
# Processing chem_18.39.png
# Successfully processed chem_18.39.png
#
# Processing chem_18.47.png
# Successfully processed chem_18.47.png
#
# Processing chem_7.4.png
# Successfully processed chem_7.4.png
#
# Processing chem_18.17.png
# Successfully processed chem_18.17.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 7s
# ├── Average time per image: 0h 0m 21s
# ├── Total progress: 80/177 (45.2%)
# ├── Total elapsed time: 0h 28m 54s
# └── Estimated time remaining: 0h 35m 3s
#
# Processing batch 15/34
# Batch contains 5 images
#
# Processing bio7.9.png
# Successfully processed bio7.9.png
#
# Processing chem_18.54.png
# Successfully processed chem_18.54.png
#
# Processing chem_18.38.png
# Successfully processed chem_18.38.png
#
# Processing chem_18.41.png
# Successfully processed chem_18.41.png
#
# Processing bio4.31.png
# Successfully processed bio4.31.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 0s
# ├── Average time per image: 0h 0m 21s
# ├── Total progress: 85/177 (48.0%)
# ├── Total elapsed time: 0h 30m 54s
# └── Estimated time remaining: 0h 33m 27s
#
# Processing batch 16/34
# Batch contains 5 images
#
# Processing bio4.27.png
# Successfully processed bio4.27.png
#
# Processing chem_18.52.png
# Successfully processed chem_18.52.png
#
# Processing chem_18.9.png
# Successfully processed chem_18.9.png
#
# Processing chem_18.63.png
# Successfully processed chem_18.63.png
#
# Processing chem_7.10.png
# Successfully processed chem_7.10.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 15s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 90/177 (50.8%)
# ├── Total elapsed time: 0h 33m 10s
# └── Estimated time remaining: 0h 32m 4s
#
# Processing batch 17/34
# Batch contains 5 images
#
# Processing chem_7.25.png
# Successfully processed chem_7.25.png
#
# Processing bio4.19.png
# Successfully processed bio4.19.png
#
# Processing chem_7.12.png
# Successfully processed chem_7.12.png
#
# Processing chem_18.29.png
# Successfully processed chem_18.29.png
#
# Processing chem_18.51.png
# Successfully processed chem_18.51.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 56s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 95/177 (53.7%)
# ├── Total elapsed time: 0h 35m 7s
# └── Estimated time remaining: 0h 30m 18s
#
# Processing batch 18/34
# Batch contains 5 images
#
# Processing chem_18.28.png
# Successfully processed chem_18.28.png
#
# Processing chem_6.27.png
# Successfully processed chem_6.27.png
#
# Processing chem_6.14.png
# Successfully processed chem_6.14.png
#
# Processing chem_18.33.png
# Successfully processed chem_18.33.png
#
# Processing chem_18.36.png
# Successfully processed chem_18.36.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 17s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 100/177 (56.5%)
# ├── Total elapsed time: 0h 37m 25s
# └── Estimated time remaining: 0h 28m 48s
#
# Processing batch 19/34
# Batch contains 5 images
#
# Processing bio4.11.png
# Successfully processed bio4.11.png
#
# Processing chem_18.14.png
# Successfully processed chem_18.14.png
#
# Processing chem_7.27.png
# Successfully processed chem_7.27.png
#
# Processing chem_18.31.png
# Successfully processed chem_18.31.png
#
# Processing chem_18.23.png
# Successfully processed chem_18.23.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 9s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 105/177 (59.3%)
# ├── Total elapsed time: 0h 39m 34s
# └── Estimated time remaining: 0h 27m 8s
#
# Processing batch 20/34
# Batch contains 5 images
#
# Processing bio7.8.png
# Successfully processed bio7.8.png
#
# Processing chem_18.48.png
# Successfully processed chem_18.48.png
#
# Processing bio4.16.png
# Successfully processed bio4.16.png
#
# Processing chem_6.7.png
# Successfully processed chem_6.7.png
#
# Processing chem_18.27.png
# Successfully processed chem_18.27.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 55s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 110/177 (62.1%)
# ├── Total elapsed time: 0h 41m 30s
# └── Estimated time remaining: 0h 25m 16s
#
# Processing batch 21/34
# Batch contains 5 images
#
# Processing bio4.2.png
# Successfully processed bio4.2.png
#
# Processing bio7.14.png
# Successfully processed bio7.14.png
#
# Processing chem_6.1.png
# Successfully processed chem_6.1.png
#
# Processing chem_6.5.png
# Successfully processed chem_6.5.png
#
# Processing bio4.30.png
# Successfully processed bio4.30.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 1s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 115/177 (65.0%)
# ├── Total elapsed time: 0h 43m 31s
# └── Estimated time remaining: 0h 23m 27s
#
# Processing batch 22/34
# Batch contains 5 images
#
# Processing bio4.17.png
# Successfully processed bio4.17.png
#
# Processing bio4.10.png
# Successfully processed bio4.10.png
#
# Processing bio7.7.png
# Successfully processed bio7.7.png
#
# Processing chem_6.18.png
# Successfully processed chem_6.18.png
#
# Processing bio7.18.png
# Successfully processed bio7.18.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 5s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 120/177 (67.8%)
# ├── Total elapsed time: 0h 45m 36s
# └── Estimated time remaining: 0h 21m 39s
#
# Processing batch 23/34
# Batch contains 5 images
#
# Processing chem_18.24.png
# Successfully processed chem_18.24.png
#
# Processing chem_6.16.png
# Successfully processed chem_6.16.png
#
# Processing chem_6.26.png
# Successfully processed chem_6.26.png
#
# Processing chem_6.8.png
# Successfully processed chem_6.8.png
#
# Processing bio4.9.png
# Successfully processed bio4.9.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 46s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 125/177 (70.6%)
# ├── Total elapsed time: 0h 47m 23s
# └── Estimated time remaining: 0h 19m 42s
#
# Processing batch 24/34
# Batch contains 5 images
#
# Processing chem_6.3.png
# Successfully processed chem_6.3.png
#
# Processing chem_18.43.png
# Successfully processed chem_18.43.png
#
# Processing chem_6.17.png
# Successfully processed chem_6.17.png
#
# Processing bio4.28.png
# Successfully processed bio4.28.png
#
# Processing bio4.18.png
# Successfully processed bio4.18.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 55s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 130/177 (73.4%)
# ├── Total elapsed time: 0h 49m 18s
# └── Estimated time remaining: 0h 17m 49s
#
# Processing batch 25/34
# Batch contains 5 images
#
# Processing chem_18.49.png
# Successfully processed chem_18.49.png
#
# Processing chem_18.58.png
# Successfully processed chem_18.58.png
#
# Processing chem_6.15.png
# Successfully processed chem_6.15.png
#
# Processing bio4.12.png
# Successfully processed bio4.12.png
#
# Processing bio4.24.png
# Successfully processed bio4.24.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 48s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 135/177 (76.3%)
# ├── Total elapsed time: 0h 51m 6s
# └── Estimated time remaining: 0h 15m 54s
#
# Processing batch 26/34
# Batch contains 5 images
#
# Processing chem_18.46.png
# Successfully processed chem_18.46.png
#
# Processing bio7.5.png
# Successfully processed bio7.5.png
#
# Processing chem_18.37.png
# Successfully processed chem_18.37.png
#
# Processing chem_7.21.png
# Successfully processed chem_7.21.png
#
# Processing chem_18.5.png
# Successfully processed chem_18.5.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 53s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 140/177 (79.1%)
# ├── Total elapsed time: 0h 52m 59s
# └── Estimated time remaining: 0h 14m 0s
#
# Processing batch 27/34
# Batch contains 5 images
#
# Processing chem_6.20.png
# Successfully processed chem_6.20.png
#
# Processing bio4.25.png
# Successfully processed bio4.25.png
#
# Processing chem_18.2.png
# Successfully processed chem_18.2.png
#
# Processing bio7.11.png
# Successfully processed bio7.11.png
#
# Processing chem_18.60.png
# Successfully processed chem_18.60.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 19s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 145/177 (81.9%)
# ├── Total elapsed time: 0h 55m 19s
# └── Estimated time remaining: 0h 12m 12s
#
# Processing batch 28/34
# Batch contains 5 images
#
# Processing chem_6.2.png
# Successfully processed chem_6.2.png
#
# Processing chem_6.6.png
# Successfully processed chem_6.6.png
#
# Processing bio4.3.png
# Successfully processed bio4.3.png
#
# Processing chem_18.10.png
# Successfully processed chem_18.10.png
#
# Processing chem_18.21.png
# Successfully processed chem_18.21.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 42s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 150/177 (84.7%)
# ├── Total elapsed time: 0h 57m 2s
# └── Estimated time remaining: 0h 10m 15s
#
# Processing batch 29/34
# Batch contains 5 images
#
# Processing chem_7.5.png
# Successfully processed chem_7.5.png
#
# Processing chem_18.12.png
# Successfully processed chem_18.12.png
#
# Processing chem_18.59.png
# Successfully processed chem_18.59.png
#
# Processing chem_18.19.png
# Successfully processed chem_18.19.png
#
# Processing chem_6.4.png
# Successfully processed chem_6.4.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 2s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 155/177 (87.6%)
# ├── Total elapsed time: 0h 59m 5s
# └── Estimated time remaining: 0h 8m 23s
#
# Processing batch 30/34
# Batch contains 5 images
#
# Processing chem_7.16.png
# Successfully processed chem_7.16.png
#
# Processing chem_7.6.png
# Successfully processed chem_7.6.png
#
# Processing bio7.10.png
# Successfully processed bio7.10.png
#
# Processing bio4.6.png
# Successfully processed bio4.6.png
#
# Processing chem_7.8.png
# Successfully processed chem_7.8.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 13s
# ├── Average time per image: 0h 0m 22s
# ├── Total progress: 160/177 (90.4%)
# ├── Total elapsed time: 1h 1m 18s
# └── Estimated time remaining: 0h 6m 30s
#
# Processing batch 31/34
# Batch contains 5 images
#
# Processing chem_6.21.png
# Successfully processed chem_6.21.png
#
# Processing bio7.6.png
# Successfully processed bio7.6.png
#
# Processing chem_7.3.png
# Successfully processed chem_7.3.png
#
# Processing bio7.17.png
# Successfully processed bio7.17.png
#
# Processing chem_18.57.png
# Successfully processed chem_18.57.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 12s
# ├── Average time per image: 0h 0m 23s
# ├── Total progress: 165/177 (93.2%)
# ├── Total elapsed time: 1h 3m 31s
# └── Estimated time remaining: 0h 4m 37s
#
# Processing batch 32/34
# Batch contains 5 images
#
# Processing chem_6.32.png
# Successfully processed chem_6.32.png
#
# Processing chem_6.10.png
# Successfully processed chem_6.10.png
#
# Processing bio7.15.png
# Successfully processed bio7.15.png
#
# Processing bio4.14.png
# Successfully processed bio4.14.png
#
# Processing chem_18.8.png
# Successfully processed chem_18.8.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 1m 57s
# ├── Average time per image: 0h 0m 23s
# ├── Total progress: 170/177 (96.0%)
# ├── Total elapsed time: 1h 5m 28s
# └── Estimated time remaining: 0h 2m 41s
#
# Processing batch 33/34
# Batch contains 5 images
#
# Processing chem_18.32.png
# Successfully processed chem_18.32.png
#
# Processing bio4.13.png
# Successfully processed bio4.13.png
#
# Processing bio7.16.png
# Successfully processed bio7.16.png
#
# Processing bio4.8b.png
# Successfully processed bio4.8b.png
#
# Processing chem_6.29.png
# Successfully processed chem_6.29.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 2m 37s
# ├── Average time per image: 0h 0m 23s
# ├── Total progress: 175/177 (98.9%)
# ├── Total elapsed time: 1h 8m 6s
# └── Estimated time remaining: 0h 0m 46s
#
# Processing batch 34/34
# Batch contains 2 images
#
# Processing chem_18.20.png
# Successfully processed chem_18.20.png
#
# Processing bio4.1.png
# Successfully processed bio4.1.png
#
# Batch Progress Update:
# ├── Time for this batch: 0h 0m 51s
# ├── Average time per image: 0h 0m 23s
# ├── Total progress: 177/177 (100.0%)
# ├── Total elapsed time: 1h 8m 58s
# └── Estimated time remaining: 0h 0m 0s
#
# === Processing Complete ===
# Total time: 1h 8m 58s
# Images processed: 177/177
# Errors encountered: 0
# Average time per image: 0h 0m 23s
# Results saved to: image_descriptions.jsonl

# %%
from PIL import Image
# Test loading one image
test_path = list(Path(input_folder).glob('*'))[0]  # get first image
try:
    img = Image.open(test_path)
    print(f"Successfully loaded test image: {test_path}")
    print(f"Image size: {img.size}")
    print(f"Image mode: {img.mode}")
except Exception as e:
    print(f"Error loading test image: {e}")
# Out:
# Successfully loaded test image: /content/Images/bio4.5.png
# Image size: (1480, 920)
# Image mode: RGBA
